# %%
from __future__ import annotations

import argparse
import json
import os
import re
import sys
from datetime import datetime
from pathlib import Path
from typing import List, Dict, Optional, Tuple
import pandas as pd

# %%
def ts() -> str:
    """Return timestamp string for logging"""
    return f"[{datetime.now().strftime('%Y%m%d %H:%M:%S')}]"

def parse_image_filename(filename: str) -> Optional[Dict[str, str]]:
    """
    Parse image filename like: SM_1_IMG_1234_20170315_143027__000001.jpg
    Returns dict with: location, image_name, date_str, time_str
    """
    # Pattern: SM_X_<imagename>_YYYYMMDD_HHMMSS__NNNNNN.ext
    # Updated to handle location like SM_1, SM_2, etc.
    pattern = r'^(SM_\d+)_(.+?)_(\d{8})_(\d{6})__\d{6}\.\w+$'
    match = re.match(pattern, filename)
    if match:
        return {
            'location': match.group(1),      # e.g., SM_1
            'image_name': match.group(2),    # e.g., IMG_1234
            'date_str': match.group(3),      # e.g., 20170315 (YYYYMMDD)
            'time_str': match.group(4)       # e.g., 143027 (HHMMSS)
        }
    return None

def parse_excel_date(date_val) -> Optional[str]:
    """
    Convert Excel date (dd-mm-yyyy or datetime object) to YYYYMMDD string
    Handles multiple input formats from Excel
    """
    if pd.isna(date_val):
        return None
    
    # If it's already a datetime object (common in pandas)
    if isinstance(date_val, datetime):
        return date_val.strftime('%Y%m%d')
    
    # If it's a string in dd-mm-yyyy or dd/mm/yyyy format
    if isinstance(date_val, str):
        date_str = date_val.strip()
        # Try dd-mm-yyyy
        for sep in ['-', '/']:
            try:
                dt = datetime.strptime(date_str, f'%d{sep}%m{sep}%Y')
                return dt.strftime('%Y%m%d')
            except:
                pass
        # Try yyyy-mm-dd (alternative format)
        try:
            dt = datetime.strptime(date_str, '%Y-%m-%d')
            return dt.strftime('%Y%m%d')
        except:
            pass
    
    return None

def parse_excel_time(time_val) -> Optional[str]:
    """
    Convert Excel time (HH:MM:SS or datetime.time object) to HHMM string
    Only extracts hours and minutes for matching
    """
    if pd.isna(time_val):
        return None
    
    # If it's a datetime.time object (most common from Excel)
    if hasattr(time_val, 'hour') and hasattr(time_val, 'minute'):
        return f"{time_val.hour:02d}{time_val.minute:02d}"
    
    # If it's a datetime object
    if isinstance(time_val, datetime):
        return time_val.strftime('%H%M')
    
    # If it's a pandas Timedelta object
    if isinstance(time_val, pd.Timedelta):
        total_seconds = int(time_val.total_seconds())
        hours = (total_seconds // 3600) % 24
        minutes = (total_seconds % 3600) // 60
        return f"{hours:02d}{minutes:02d}"
    
    # If it's a string in HH:MM:SS format
    if isinstance(time_val, str):
        try:
            parts = time_val.strip().split(':')
            if len(parts) >= 2:
                hh = int(parts[0])
                mm = int(parts[1])
                return f"{hh:02d}{mm:02d}"
        except:
            pass
    
    return None

def time_diff_minutes(time1_hhmm: str, time2_hhmm: str) -> int:
    """
    Calculate difference in minutes between two times in HHMM format
    Returns time1 - time2 in minutes
    """
    try:
        h1, m1 = int(time1_hhmm[:2]), int(time1_hhmm[2:4])
        h2, m2 = int(time2_hhmm[:2]), int(time2_hhmm[2:4])
        
        total_min1 = h1 * 60 + m1
        total_min2 = h2 * 60 + m2
        
        return total_min1 - total_min2
    except:
        return 999  # Return large number if parsing fails

def discover_images(img_dir: str, allowed_exts: set[str]) -> List[Tuple[str, Dict]]:
    """
    Recursively find all images and parse their metadata
    Returns list of (full_path, parsed_metadata)
    """
    images = []
    img_dir_abs = os.path.abspath(img_dir)
    
    print(f"{ts()} Scanning directory: {img_dir_abs}")
    
    for root, dirs, files in os.walk(img_dir_abs):
        for fn in files:
            ext = os.path.splitext(fn)[1].lower()
            if ext in allowed_exts:
                parsed = parse_image_filename(fn)
                if parsed:
                    full_path = os.path.join(root, fn)
                    images.append((full_path, parsed))
                else:
                    # Image doesn't match expected naming pattern
                    pass
    
    return images

def match_label_to_image(
    label_row: pd.Series,
    images: List[Tuple[str, Dict]],
    verbose: bool = False
) -> Optional[str]:
    """
    Find matching image for a label row based on:
    1. Location (exact match) - e.g., SM_1
    2. ImageName (exact match) - e.g., IMG_1234
    3. TrueDate (exact match) - converted to YYYYMMDD
    4. TrueTime (within ±2 minutes) - only HH:MM compared
    
    Returns image path if found, else None
    """
    # Parse label data
    label_location = str(label_row.get('Location', '')).strip()
    label_image_name = str(label_row.get('ImageName', '')).strip()
    label_date = parse_excel_date(label_row.get('TrueDate'))
    label_time = parse_excel_time(label_row.get('TrueTime'))
    
    # Check if all required fields are present
    if not label_location or label_location == 'nan':
        if verbose:
            print(f"{ts()}   Missing Location")
        return None
    if not label_image_name or label_image_name == 'nan':
        if verbose:
            print(f"{ts()}   Missing ImageName")
        return None
    if not label_date:
        if verbose:
            print(f"{ts()}   Missing/Invalid TrueDate")
        return None
    if not label_time:
        if verbose:
            print(f"{ts()}   Missing/Invalid TrueTime")
        return None
    
    if verbose:
        print(f"{ts()}   Looking for: {label_location} / {label_image_name} / {label_date} / {label_time}")
    
    # Search through images
    for img_path, img_meta in images:
        # 1. Location exact match
        if img_meta['location'] != label_location:
            continue
        
        # 2. ImageName exact match
        if img_meta['image_name'] != label_image_name:
            continue
        
        # 3. Date exact match
        if img_meta['date_str'] != label_date:
            continue
        
        # 4. Time within ±2 minutes (only HH and MM)
        img_time_hhmm = img_meta['time_str'][:4]  # Extract HHMM from HHMMSS
        label_time_hhmm = label_time
        
        diff = time_diff_minutes(img_time_hhmm, label_time_hhmm)
        
        if verbose:
            print(f"{ts()}   Checking {os.path.basename(img_path)}: time diff = {diff} minutes")
        
        if -2 <= diff <= 2:
            if verbose:
                print(f"{ts()}   MATCH FOUND: {img_path}")
            return img_path
    
    if verbose:
        print(f"{ts()}   No match found")
    
    return None

# %%
def main():
    parser = argparse.ArgumentParser(
        description="Match camera trap labels with processed images and create JSON + updated Excel"
    )
    parser.add_argument("--label-file", required=True, help="Path to Excel label file")
    parser.add_argument("--img-dir", required=True, help="Root directory containing processed images")
    parser.add_argument("--output-json", required=True, help="Output JSON file path")
    parser.add_argument("--output-excel", required=True, help="Output Excel file with image paths")
    parser.add_argument("--exts", default="jpg,jpeg", help="Comma-separated image extensions (default: jpg,jpeg)")
    parser.add_argument("--verbose", action="store_true", help="Enable verbose output for debugging")
    parser.add_argument("--sample", type=int, default=0, help="Process only first N rows (for testing)")
    args = parser.parse_args()
    
    if not PANDAS_OK:
        print(f"{ts()} ERROR: pandas required but not available")
        print(f"{ts()} Install with: pip install pandas openpyxl")
        return
    
    # Normalize extensions
    exts = {("." + e.strip().lower().lstrip(".")) for e in args.exts.split(",") if e.strip()}
    
    print(f"{ts()} ========================================")
    print(f"{ts()} Camera Trap Label-Image Matcher")
    print(f"{ts()} ========================================")
    print(f"{ts()} Label file: {args.label_file}")
    print(f"{ts()} Image directory: {args.img_dir}")
    print(f"{ts()} Output JSON: {args.output_json}")
    print(f"{ts()} Output Excel: {args.output_excel}")
    print(f"{ts()} Extensions: {sorted(exts)}")
    print(f"{ts()} ========================================")
    
    # Load Excel file
    print(f"{ts()} Loading label file...")
    try:
        df = pd.read_excel(args.label_file)
    except Exception as e:
        print(f"{ts()} ERROR loading Excel: {e}")
        return
    
    print(f"{ts()} Loaded {len(df)} label rows")
    print(f"{ts()} Columns found: {list(df.columns)}")
    
    # Verify required columns exist
    required_cols = ['Location', 'ImageName', 'TrueDate', 'TrueTime']
    missing_cols = [col for col in required_cols if col not in df.columns]
    if missing_cols:
        print(f"{ts()} ERROR: Missing required columns: {missing_cols}")
        return
    
    # Optional columns for output
    optional_cols = ['CommonName', 'ScientificName', 'Number', 'Sex', 'Notes', 'BestPhoto']
    
    # Limit to sample if specified
    if args.sample > 0:
        print(f"{ts()} WARNING: Processing only first {args.sample} rows (--sample mode)")
        df = df.head(args.sample)
    
    # Discover all images
    print(f"{ts()} Scanning images in: {args.img_dir}")
    images = discover_images(args.img_dir, exts)
    print(f"{ts()} Found {len(images)} images with valid filenames")
    
    if len(images) == 0:
        print(f"{ts()} WARNING: No images found. Check the image directory and file naming pattern.")
        return
    
    # Show sample images
    print(f"{ts()} Sample images (first 5):")
    for i, (path, meta) in enumerate(images[:5]):
        print(f"{ts()}   {i+1}. {os.path.basename(path)}")
        print(f"{ts()}      Location: {meta['location']}, Name: {meta['image_name']}, Date: {meta['date_str']}, Time: {meta['time_str']}")
    
    # Matching process
    print(f"{ts()} ========================================")
    print(f"{ts()} Starting matching process...")
    print(f"{ts()} ========================================")
    
    matches = []
    matched_count = 0
    
    # Add ImagePath column to dataframe
    df['ImagePath'] = None
    
    for idx, row in df.iterrows():
        if args.verbose or (idx + 1) % 100 == 1:
            print(f"{ts()} Processing row {idx + 1}/{len(df)}...")
        
        img_path = match_label_to_image(row, images, verbose=args.verbose)
        
        if img_path:
            matched_count += 1
            df.at[idx, 'ImagePath'] = img_path
            
            # Build JSON entry with available fields
            json_entry = {
                'image_path': img_path,
            }
            
            # Add optional fields if they exist in the dataframe
            for col in optional_cols:
                if col in df.columns:
                    val = row.get(col, '')
                    # Convert to string, handle NaN
                    if pd.isna(val):
                        json_entry[col] = ''
                    else:
                        json_entry[col] = str(val)
                else:
                    json_entry[col] = ''
            
            matches.append(json_entry)
        
        # Progress updates every 100 rows
        if (idx + 1) % 100 == 0:
            print(f"{ts()} Progress: {idx + 1}/{len(df)} labels processed, {matched_count} matched ({matched_count/(idx+1)*100:.1f}%)")
    
    print(f"{ts()} ========================================")
    print(f"{ts()} Matching complete!")
    print(f"{ts()} ========================================")
    
    # Write JSON output
    print(f"{ts()} Writing JSON to: {args.output_json}")
    try:
        os.makedirs(os.path.dirname(args.output_json), exist_ok=True)
        with open(args.output_json, 'w') as f:
            json.dump(matches, f, indent=2)
        print(f"{ts()} JSON written successfully ({len(matches)} entries)")
    except Exception as e:
        print(f"{ts()} ERROR writing JSON: {e}")
    
    # Write updated Excel
    print(f"{ts()} Writing Excel to: {args.output_excel}")
    try:
        os.makedirs(os.path.dirname(args.output_excel), exist_ok=True)
        df.to_excel(args.output_excel, index=False)
        print(f"{ts()} Excel written successfully")
    except Exception as e:
        print(f"{ts()} ERROR writing Excel: {e}")
    
    # Final summary
    print(f"{ts()} ========================================")
    print(f"{ts()} FINAL SUMMARY")
    print(f"{ts()} ========================================")
    print(f"{ts()} Total labels processed: {len(df)}")
    print(f"{ts()} Successfully matched: {matched_count}")
    print(f"{ts()} Unmatched: {len(df) - matched_count}")
    print(f"{ts()} Match rate: {matched_count/len(df)*100:.1f}%")
    print(f"{ts()} ========================================")
    print(f"{ts()} DONE!")

# %%
# You can comment out this section when running from command line
sys.argv = [
    "Convert_label_csv_file_to_json_format_v5.ipynb",
    "--label-file", "/home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Final_Label.xlsx",
    "--img-dir", "/home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Processed_Images/",
    "--output-json", "/home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Label.json",
    "--output-excel", "/home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Final_Label_with_paths.xlsx",
    # "--verbose",  # Uncomment for detailed debugging
    # "--sample", "10",  # Uncomment to test with first 10 rows only
]
main()
# Out:
# [20251102 06:43:54] ========================================
# [20251102 06:43:54] Camera Trap Label-Image Matcher
# [20251102 06:43:54] ========================================
# [20251102 06:43:54] Label file: /home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Final_Label.xlsx
# [20251102 06:43:54] Image directory: /home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Processed_Images/
# [20251102 06:43:54] Output JSON: /home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Label.json
# [20251102 06:43:54] Output Excel: /home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Final_Label_with_paths.xlsx
# [20251102 06:43:54] Extensions: ['.jpeg', '.jpg']
# [20251102 06:43:54] ========================================
# [20251102 06:43:54] Loading label file...
# [20251102 06:43:57] Loaded 23351 label rows
# [20251102 06:43:57] Columns found: ['Location', 'ImageName', 'CameraDate', 'CameraDate_InDateFormat', 'CameraTime', 'TrueDate', 'TrueTime', 'CommonName', 'ScientificName', 'Number', 'SameIndividual', 'Sex', 'Notes', 'BestPhoto']
# [20251102 06:43:57] Scanning images in: /home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Processed_Images/
# [20251102 06:43:57] Scanning directory: /home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Processed_Images
# [20251102 06:43:57] Found 56472 images with valid filenames
# [20251102 06:43:57] Sample images (first 5):
# [20251102 06:43:57]   1. SM_1_IMG_0007_20220309_185600__003854.JPG
# [20251102 06:43:57]      Location: SM_1, Name: IMG_0007, Date: 20220309, Time: 185600
# [20251102 06:43:57]   2. SM_1_IMG_0009_20220309_185600__004176.JPG
# [20251102 06:43:57]      Location: SM_1, Name: IMG_0009, Date: 20220309, Time: 185600
# [20251102 06:43:57]   3. SM_1_IMG_0008_20220309_185600__005074.JPG
# [20251102 06:43:57]      Location: SM_1, Name: IMG_0008, Date: 20220309, Time: 185600
# [20251102 06:43:57]   4. SM_1_IMG_0365_20230515_203300__009310.JPG
# [20251102 06:43:57]      Location: SM_1, Name: IMG_0365, Date: 20230515, Time: 203300
# [20251102 06:43:57]   5. SM_1_IMG_0360_20230515_203200__008645.JPG
# [20251102 06:43:57]      Location: SM_1, Name: IMG_0360, Date: 20230515, Time: 203200
# [20251102 06:43:57] ========================================
# [20251102 06:43:57] Starting matching process...
# [20251102 06:43:57] ========================================
# [20251102 06:43:57] Processing row 1/23351...
# [20251102 06:43:57] Progress: 100/23351 labels processed, 80 matched (80.0%)
# [20251102 06:43:57] Processing row 101/23351...
# [20251102 06:43:58] Progress: 200/23351 labels processed, 131 matched (65.5%)
# [20251102 06:43:58] Processing row 201/23351...
# [20251102 06:43:58] Progress: 300/23351 labels processed, 189 matched (63.0%)
# [20251102 06:43:58] Processing row 301/23351...
# [20251102 06:43:58] Progress: 400/23351 labels processed, 256 matched (64.0%)
# [20251102 06:43:58] Processing row 401/23351...
# [20251102 06:43:58] Progress: 500/23351 labels processed, 323 matched (64.6%)
# [20251102 06:43:58] Processing row 501/23351...
# [20251102 06:43:58] Progress: 600/23351 labels processed, 401 matched (66.8%)
# [20251102 06:43:58] Processing row 601/23351...
# [20251102 06:43:58] Progress: 700/23351 labels processed, 484 matched (69.1%)
# [20251102 06:43:58] Processing row 701/23351...
# [20251102 06:43:58] Progress: 800/23351 labels processed, 565 matched (70.6%)
# [20251102 06:43:58] Processing row 801/23351...
# [20251102 06:43:58] Progress: 900/23351 labels processed, 653 matched (72.6%)
# [20251102 06:43:58] Processing row 901/23351...
# [20251102 06:43:59] Progress: 1000/23351 labels processed, 739 matched (73.9%)
# [20251102 06:43:59] Processing row 1001/23351...
# [20251102 06:43:59] Progress: 1100/23351 labels processed, 823 matched (74.8%)
# [20251102 06:43:59] Processing row 1101/23351...
# [20251102 06:43:59] Progress: 1200/23351 labels processed, 905 matched (75.4%)
# [20251102 06:43:59] Processing row 1201/23351...
# [20251102 06:43:59] Progress: 1300/23351 labels processed, 989 matched (76.1%)
# [20251102 06:43:59] Processing row 1301/23351...
# [20251102 06:43:59] Progress: 1400/23351 labels processed, 1069 matched (76.4%)
# [20251102 06:43:59] Processing row 1401/23351...
# [20251102 06:43:59] Progress: 1500/23351 labels processed, 1125 matched (75.0%)
# [20251102 06:43:59] Processing row 1501/23351...
# [20251102 06:43:59] Progress: 1600/23351 labels processed, 1181 matched (73.8%)
# [20251102 06:43:59] Processing row 1601/23351...
# [20251102 06:44:00] Progress: 1700/23351 labels processed, 1248 matched (73.4%)
# [20251102 06:44:00] Processing row 1701/23351...
# [20251102 06:44:00] Progress: 1800/23351 labels processed, 1314 matched (73.0%)
# [20251102 06:44:00] Processing row 1801/23351...
# [20251102 06:44:00] Progress: 1900/23351 labels processed, 1374 matched (72.3%)
# [20251102 06:44:00] Processing row 1901/23351...
# [20251102 06:44:00] Progress: 2000/23351 labels processed, 1434 matched (71.7%)
# [20251102 06:44:00] Processing row 2001/23351...
# [20251102 06:44:00] Progress: 2100/23351 labels processed, 1491 matched (71.0%)
# [20251102 06:44:00] Processing row 2101/23351...
# [20251102 06:44:00] Progress: 2200/23351 labels processed, 1550 matched (70.5%)
# [20251102 06:44:00] Processing row 2201/23351...
# [20251102 06:44:01] Progress: 2300/23351 labels processed, 1605 matched (69.8%)
# [20251102 06:44:01] Processing row 2301/23351...
# [20251102 06:44:01] Progress: 2400/23351 labels processed, 1666 matched (69.4%)
# [20251102 06:44:01] Processing row 2401/23351...
# [20251102 06:44:01] Progress: 2500/23351 labels processed, 1731 matched (69.2%)
# [20251102 06:44:01] Processing row 2501/23351...
# [20251102 06:44:01] Progress: 2600/23351 labels processed, 1814 matched (69.8%)
# [20251102 06:44:01] Processing row 2601/23351...
# [20251102 06:44:01] Progress: 2700/23351 labels processed, 1896 matched (70.2%)
# [20251102 06:44:01] Processing row 2701/23351...
# [20251102 06:44:01] Progress: 2800/23351 labels processed, 1989 matched (71.0%)
# [20251102 06:44:01] Processing row 2801/23351...
# [20251102 06:44:01] Progress: 2900/23351 labels processed, 2086 matched (71.9%)
# [20251102 06:44:01] Processing row 2901/23351...
# [20251102 06:44:01] Progress: 3000/23351 labels processed, 2186 matched (72.9%)
# [20251102 06:44:01] Processing row 3001/23351...
# [20251102 06:44:01] Progress: 3100/23351 labels processed, 2286 matched (73.7%)
# [20251102 06:44:01] Processing row 3101/23351...
# [20251102 06:44:02] Progress: 3200/23351 labels processed, 2386 matched (74.6%)
# [20251102 06:44:02] Processing row 3201/23351...
# [20251102 06:44:02] Progress: 3300/23351 labels processed, 2486 matched (75.3%)
# [20251102 06:44:02] Processing row 3301/23351...
# [20251102 06:44:02] Progress: 3400/23351 labels processed, 2575 matched (75.7%)
# [20251102 06:44:02] Processing row 3401/23351...
# [20251102 06:44:02] Progress: 3500/23351 labels processed, 2664 matched (76.1%)
# [20251102 06:44:02] Processing row 3501/23351...
# [20251102 06:44:02] Progress: 3600/23351 labels processed, 2751 matched (76.4%)
# [20251102 06:44:02] Processing row 3601/23351...
# [20251102 06:44:02] Progress: 3700/23351 labels processed, 2847 matched (76.9%)
# [20251102 06:44:02] Processing row 3701/23351...
# [20251102 06:44:02] Progress: 3800/23351 labels processed, 2941 matched (77.4%)
# [20251102 06:44:02] Processing row 3801/23351...
# [20251102 06:44:02] Progress: 3900/23351 labels processed, 3041 matched (78.0%)
# [20251102 06:44:02] Processing row 3901/23351...
# [20251102 06:44:02] Progress: 4000/23351 labels processed, 3128 matched (78.2%)
# [20251102 06:44:02] Processing row 4001/23351...
# [20251102 06:44:03] Progress: 4100/23351 labels processed, 3206 matched (78.2%)
# [20251102 06:44:03] Processing row 4101/23351...
# [20251102 06:44:03] Progress: 4200/23351 labels processed, 3293 matched (78.4%)
# [20251102 06:44:03] Processing row 4201/23351...
# [20251102 06:44:03] Progress: 4300/23351 labels processed, 3372 matched (78.4%)
# [20251102 06:44:03] Processing row 4301/23351...
# [20251102 06:44:03] Progress: 4400/23351 labels processed, 3455 matched (78.5%)
# [20251102 06:44:03] Processing row 4401/23351...
# [20251102 06:44:03] Progress: 4500/23351 labels processed, 3533 matched (78.5%)
# [20251102 06:44:03] Processing row 4501/23351...
# [20251102 06:44:03] Progress: 4600/23351 labels processed, 3605 matched (78.4%)
# [20251102 06:44:03] Processing row 4601/23351...
# [20251102 06:44:03] Progress: 4700/23351 labels processed, 3673 matched (78.1%)
# [20251102 06:44:03] Processing row 4701/23351...
# [20251102 06:44:03] Progress: 4800/23351 labels processed, 3752 matched (78.2%)
# [20251102 06:44:03] Processing row 4801/23351...
# [20251102 06:44:04] Progress: 4900/23351 labels processed, 3830 matched (78.2%)
# [20251102 06:44:04] Processing row 4901/23351...
# [20251102 06:44:04] Progress: 5000/23351 labels processed, 3897 matched (77.9%)
# [20251102 06:44:04] Processing row 5001/23351...
# [20251102 06:44:04] Progress: 5100/23351 labels processed, 3953 matched (77.5%)
# [20251102 06:44:04] Processing row 5101/23351...
# [20251102 06:44:04] Progress: 5200/23351 labels processed, 4012 matched (77.2%)
# [20251102 06:44:04] Processing row 5201/23351...
# [20251102 06:44:04] Progress: 5300/23351 labels processed, 4069 matched (76.8%)
# [20251102 06:44:04] Processing row 5301/23351...
# [20251102 06:44:05] Progress: 5400/23351 labels processed, 4118 matched (76.3%)
# [20251102 06:44:05] Processing row 5401/23351...
# [20251102 06:44:05] Progress: 5500/23351 labels processed, 4167 matched (75.8%)
# [20251102 06:44:05] Processing row 5501/23351...
# [20251102 06:44:05] Progress: 5600/23351 labels processed, 4208 matched (75.1%)
# [20251102 06:44:05] Processing row 5601/23351...
# [20251102 06:44:05] Progress: 5700/23351 labels processed, 4262 matched (74.8%)
# [20251102 06:44:05] Processing row 5701/23351...
# [20251102 06:44:05] Progress: 5800/23351 labels processed, 4317 matched (74.4%)
# [20251102 06:44:05] Processing row 5801/23351...
# [20251102 06:44:05] Progress: 5900/23351 labels processed, 4381 matched (74.3%)
# [20251102 06:44:05] Processing row 5901/23351...
# [20251102 06:44:06] Progress: 6000/23351 labels processed, 4445 matched (74.1%)
# [20251102 06:44:06] Processing row 6001/23351...
# [20251102 06:44:06] Progress: 6100/23351 labels processed, 4508 matched (73.9%)
# [20251102 06:44:06] Processing row 6101/23351...
# [20251102 06:44:06] Progress: 6200/23351 labels processed, 4573 matched (73.8%)
# [20251102 06:44:06] Processing row 6201/23351...
# [20251102 06:44:06] Progress: 6300/23351 labels processed, 4622 matched (73.4%)
# [20251102 06:44:06] Processing row 6301/23351...
# [20251102 06:44:06] Progress: 6400/23351 labels processed, 4697 matched (73.4%)
# [20251102 06:44:06] Processing row 6401/23351...
# [20251102 06:44:06] Progress: 6500/23351 labels processed, 4774 matched (73.4%)
# [20251102 06:44:06] Processing row 6501/23351...
# [20251102 06:44:07] Progress: 6600/23351 labels processed, 4871 matched (73.8%)
# [20251102 06:44:07] Processing row 6601/23351...
# [20251102 06:44:07] Progress: 6700/23351 labels processed, 4971 matched (74.2%)
# [20251102 06:44:07] Processing row 6701/23351...
# [20251102 06:44:07] Progress: 6800/23351 labels processed, 5050 matched (74.3%)
# [20251102 06:44:07] Processing row 6801/23351...
# [20251102 06:44:07] Progress: 6900/23351 labels processed, 5141 matched (74.5%)
# [20251102 06:44:07] Processing row 6901/23351...
# [20251102 06:44:07] Progress: 7000/23351 labels processed, 5241 matched (74.9%)
# [20251102 06:44:07] Processing row 7001/23351...
# [20251102 06:44:07] Progress: 7100/23351 labels processed, 5341 matched (75.2%)
# [20251102 06:44:07] Processing row 7101/23351...
# [20251102 06:44:07] Progress: 7200/23351 labels processed, 5441 matched (75.6%)
# [20251102 06:44:07] Processing row 7201/23351...
# [20251102 06:44:07] Progress: 7300/23351 labels processed, 5541 matched (75.9%)
# [20251102 06:44:07] Processing row 7301/23351...
# [20251102 06:44:07] Progress: 7400/23351 labels processed, 5641 matched (76.2%)
# [20251102 06:44:07] Processing row 7401/23351...
# [20251102 06:44:07] Progress: 7500/23351 labels processed, 5739 matched (76.5%)
# [20251102 06:44:07] Processing row 7501/23351...
# [20251102 06:44:07] Progress: 7600/23351 labels processed, 5838 matched (76.8%)
# [20251102 06:44:07] Processing row 7601/23351...
# [20251102 06:44:08] Progress: 7700/23351 labels processed, 5938 matched (77.1%)
# [20251102 06:44:08] Processing row 7701/23351...
# [20251102 06:44:08] Progress: 7800/23351 labels processed, 6038 matched (77.4%)
# [20251102 06:44:08] Processing row 7801/23351...
# [20251102 06:44:08] Progress: 7900/23351 labels processed, 6138 matched (77.7%)
# [20251102 06:44:08] Processing row 7901/23351...
# [20251102 06:44:08] Progress: 8000/23351 labels processed, 6238 matched (78.0%)
# [20251102 06:44:08] Processing row 8001/23351...
# [20251102 06:44:08] Progress: 8100/23351 labels processed, 6335 matched (78.2%)
# [20251102 06:44:08] Processing row 8101/23351...
# [20251102 06:44:08] Progress: 8200/23351 labels processed, 6435 matched (78.5%)
# [20251102 06:44:08] Processing row 8201/23351...
# [20251102 06:44:08] Progress: 8300/23351 labels processed, 6529 matched (78.7%)
# [20251102 06:44:08] Processing row 8301/23351...
# [20251102 06:44:08] Progress: 8400/23351 labels processed, 6629 matched (78.9%)
# [20251102 06:44:08] Processing row 8401/23351...
# [20251102 06:44:09] Progress: 8500/23351 labels processed, 6726 matched (79.1%)
# [20251102 06:44:09] Processing row 8501/23351...
# [20251102 06:44:09] Progress: 8600/23351 labels processed, 6814 matched (79.2%)
# [20251102 06:44:09] Processing row 8601/23351...
# [20251102 06:44:09] Progress: 8700/23351 labels processed, 6868 matched (78.9%)
# [20251102 06:44:09] Processing row 8701/23351...
# [20251102 06:44:09] Progress: 8800/23351 labels processed, 6922 matched (78.7%)
# [20251102 06:44:09] Processing row 8801/23351...
# [20251102 06:44:09] Progress: 8900/23351 labels processed, 6974 matched (78.4%)
# [20251102 06:44:09] Processing row 8901/23351...
# [20251102 06:44:09] Progress: 9000/23351 labels processed, 7016 matched (78.0%)
# [20251102 06:44:09] Processing row 9001/23351...
# [20251102 06:44:10] Progress: 9100/23351 labels processed, 7066 matched (77.6%)
# [20251102 06:44:10] Processing row 9101/23351...
# [20251102 06:44:10] Progress: 9200/23351 labels processed, 7136 matched (77.6%)
# [20251102 06:44:10] Processing row 9201/23351...
# [20251102 06:44:10] Progress: 9300/23351 labels processed, 7236 matched (77.8%)
# [20251102 06:44:10] Processing row 9301/23351...
# [20251102 06:44:10] Progress: 9400/23351 labels processed, 7336 matched (78.0%)
# [20251102 06:44:10] Processing row 9401/23351...
# [20251102 06:44:10] Progress: 9500/23351 labels processed, 7436 matched (78.3%)
# [20251102 06:44:10] Processing row 9501/23351...
# [20251102 06:44:10] Progress: 9600/23351 labels processed, 7527 matched (78.4%)
# [20251102 06:44:10] Processing row 9601/23351...
# [20251102 06:44:10] Progress: 9700/23351 labels processed, 7627 matched (78.6%)
# [20251102 06:44:10] Processing row 9701/23351...
# [20251102 06:44:10] Progress: 9800/23351 labels processed, 7727 matched (78.8%)
# [20251102 06:44:10] Processing row 9801/23351...
# [20251102 06:44:10] Progress: 9900/23351 labels processed, 7822 matched (79.0%)
# [20251102 06:44:10] Processing row 9901/23351...
# [20251102 06:44:11] Progress: 10000/23351 labels processed, 7918 matched (79.2%)
# [20251102 06:44:11] Processing row 10001/23351...
# [20251102 06:44:11] Progress: 10100/23351 labels processed, 8018 matched (79.4%)
# [20251102 06:44:11] Processing row 10101/23351...
# [20251102 06:44:11] Progress: 10200/23351 labels processed, 8118 matched (79.6%)
# [20251102 06:44:11] Processing row 10201/23351...
# [20251102 06:44:11] Progress: 10300/23351 labels processed, 8218 matched (79.8%)
# [20251102 06:44:11] Processing row 10301/23351...
# [20251102 06:44:11] Progress: 10400/23351 labels processed, 8318 matched (80.0%)
# [20251102 06:44:11] Processing row 10401/23351...
# [20251102 06:44:11] Progress: 10500/23351 labels processed, 8418 matched (80.2%)
# [20251102 06:44:11] Processing row 10501/23351...
# [20251102 06:44:11] Progress: 10600/23351 labels processed, 8515 matched (80.3%)
# [20251102 06:44:11] Processing row 10601/23351...
# [20251102 06:44:11] Progress: 10700/23351 labels processed, 8615 matched (80.5%)
# [20251102 06:44:11] Processing row 10701/23351...
# [20251102 06:44:11] Progress: 10800/23351 labels processed, 8715 matched (80.7%)
# [20251102 06:44:11] Processing row 10801/23351...
# [20251102 06:44:11] Progress: 10900/23351 labels processed, 8815 matched (80.9%)
# [20251102 06:44:11] Processing row 10901/23351...
# [20251102 06:44:11] Progress: 11000/23351 labels processed, 8912 matched (81.0%)
# [20251102 06:44:11] Processing row 11001/23351...
# [20251102 06:44:12] Progress: 11100/23351 labels processed, 9012 matched (81.2%)
# [20251102 06:44:12] Processing row 11101/23351...
# [20251102 06:44:12] Progress: 11200/23351 labels processed, 9112 matched (81.4%)
# [20251102 06:44:12] Processing row 11201/23351...
# [20251102 06:44:12] Progress: 11300/23351 labels processed, 9212 matched (81.5%)
# [20251102 06:44:12] Processing row 11301/23351...
# [20251102 06:44:12] Progress: 11400/23351 labels processed, 9311 matched (81.7%)
# [20251102 06:44:12] Processing row 11401/23351...
# [20251102 06:44:12] Progress: 11500/23351 labels processed, 9411 matched (81.8%)
# [20251102 06:44:12] Processing row 11501/23351...
# [20251102 06:44:12] Progress: 11600/23351 labels processed, 9508 matched (82.0%)
# [20251102 06:44:12] Processing row 11601/23351...
# [20251102 06:44:12] Progress: 11700/23351 labels processed, 9608 matched (82.1%)
# [20251102 06:44:12] Processing row 11701/23351...
# [20251102 06:44:12] Progress: 11800/23351 labels processed, 9705 matched (82.2%)
# [20251102 06:44:12] Processing row 11801/23351...
# [20251102 06:44:12] Progress: 11900/23351 labels processed, 9805 matched (82.4%)
# [20251102 06:44:12] Processing row 11901/23351...
# [20251102 06:44:12] Progress: 12000/23351 labels processed, 9905 matched (82.5%)
# [20251102 06:44:12] Processing row 12001/23351...
# [20251102 06:44:12] Progress: 12100/23351 labels processed, 10005 matched (82.7%)
# [20251102 06:44:12] Processing row 12101/23351...
# [20251102 06:44:13] Progress: 12200/23351 labels processed, 10105 matched (82.8%)
# [20251102 06:44:13] Processing row 12201/23351...
# [20251102 06:44:13] Progress: 12300/23351 labels processed, 10193 matched (82.9%)
# [20251102 06:44:13] Processing row 12301/23351...
# [20251102 06:44:13] Progress: 12400/23351 labels processed, 10293 matched (83.0%)
# [20251102 06:44:13] Processing row 12401/23351...
# [20251102 06:44:13] Progress: 12500/23351 labels processed, 10393 matched (83.1%)
# [20251102 06:44:13] Processing row 12501/23351...
# [20251102 06:44:13] Progress: 12600/23351 labels processed, 10493 matched (83.3%)
# [20251102 06:44:13] Processing row 12601/23351...
# [20251102 06:44:13] Progress: 12700/23351 labels processed, 10593 matched (83.4%)
# [20251102 06:44:13] Processing row 12701/23351...
# [20251102 06:44:13] Progress: 12800/23351 labels processed, 10693 matched (83.5%)
# [20251102 06:44:13] Processing row 12801/23351...
# [20251102 06:44:13] Progress: 12900/23351 labels processed, 10793 matched (83.7%)
# [20251102 06:44:13] Processing row 12901/23351...
# [20251102 06:44:13] Progress: 13000/23351 labels processed, 10890 matched (83.8%)
# [20251102 06:44:13] Processing row 13001/23351...
# [20251102 06:44:13] Progress: 13100/23351 labels processed, 10990 matched (83.9%)
# [20251102 06:44:13] Processing row 13101/23351...
# [20251102 06:44:13] Progress: 13200/23351 labels processed, 11087 matched (84.0%)
# [20251102 06:44:13] Processing row 13201/23351...
# [20251102 06:44:14] Progress: 13300/23351 labels processed, 11187 matched (84.1%)
# [20251102 06:44:14] Processing row 13301/23351...
# [20251102 06:44:14] Progress: 13400/23351 labels processed, 11287 matched (84.2%)
# [20251102 06:44:14] Processing row 13401/23351...
# [20251102 06:44:14] Progress: 13500/23351 labels processed, 11387 matched (84.3%)
# [20251102 06:44:14] Processing row 13501/23351...
# [20251102 06:44:14] Progress: 13600/23351 labels processed, 11487 matched (84.5%)
# [20251102 06:44:14] Processing row 13601/23351...
# [20251102 06:44:14] Progress: 13700/23351 labels processed, 11587 matched (84.6%)
# [20251102 06:44:14] Processing row 13701/23351...
# [20251102 06:44:14] Progress: 13800/23351 labels processed, 11687 matched (84.7%)
# [20251102 06:44:14] Processing row 13801/23351...
# [20251102 06:44:14] Progress: 13900/23351 labels processed, 11787 matched (84.8%)
# [20251102 06:44:14] Processing row 13901/23351...
# [20251102 06:44:14] Progress: 14000/23351 labels processed, 11873 matched (84.8%)
# [20251102 06:44:14] Processing row 14001/23351...
# [20251102 06:44:15] Progress: 14100/23351 labels processed, 11892 matched (84.3%)
# [20251102 06:44:15] Processing row 14101/23351...
# [20251102 06:44:15] Progress: 14200/23351 labels processed, 11930 matched (84.0%)
# [20251102 06:44:15] Processing row 14201/23351...
# [20251102 06:44:15] Progress: 14300/23351 labels processed, 11981 matched (83.8%)
# [20251102 06:44:15] Processing row 14301/23351...
# [20251102 06:44:15] Progress: 14400/23351 labels processed, 12011 matched (83.4%)
# [20251102 06:44:15] Processing row 14401/23351...
# [20251102 06:44:16] Progress: 14500/23351 labels processed, 12034 matched (83.0%)
# [20251102 06:44:16] Processing row 14501/23351...
# [20251102 06:44:16] Progress: 14600/23351 labels processed, 12034 matched (82.4%)
# [20251102 06:44:16] Processing row 14601/23351...
# [20251102 06:44:16] Progress: 14700/23351 labels processed, 12037 matched (81.9%)
# [20251102 06:44:16] Processing row 14701/23351...
# [20251102 06:44:17] Progress: 14800/23351 labels processed, 12037 matched (81.3%)
# [20251102 06:44:17] Processing row 14801/23351...
# [20251102 06:44:17] Progress: 14900/23351 labels processed, 12037 matched (80.8%)
# [20251102 06:44:17] Processing row 14901/23351...
# [20251102 06:44:17] Progress: 15000/23351 labels processed, 12037 matched (80.2%)
# [20251102 06:44:17] Processing row 15001/23351...
# [20251102 06:44:18] Progress: 15100/23351 labels processed, 12045 matched (79.8%)
# [20251102 06:44:18] Processing row 15101/23351...
# [20251102 06:44:18] Progress: 15200/23351 labels processed, 12049 matched (79.3%)
# [20251102 06:44:18] Processing row 15201/23351...
# [20251102 06:44:18] Progress: 15300/23351 labels processed, 12049 matched (78.8%)
# [20251102 06:44:18] Processing row 15301/23351...
# [20251102 06:44:18] Progress: 15400/23351 labels processed, 12049 matched (78.2%)
# [20251102 06:44:18] Processing row 15401/23351...
# [20251102 06:44:19] Progress: 15500/23351 labels processed, 12049 matched (77.7%)
# [20251102 06:44:19] Processing row 15501/23351...
# [20251102 06:44:19] Progress: 15600/23351 labels processed, 12049 matched (77.2%)
# [20251102 06:44:19] Processing row 15601/23351...
# [20251102 06:44:19] Progress: 15700/23351 labels processed, 12049 matched (76.7%)
# [20251102 06:44:19] Processing row 15701/23351...
# [20251102 06:44:20] Progress: 15800/23351 labels processed, 12049 matched (76.3%)
# [20251102 06:44:20] Processing row 15801/23351...
# [20251102 06:44:20] Progress: 15900/23351 labels processed, 12049 matched (75.8%)
# [20251102 06:44:20] Processing row 15901/23351...
# [20251102 06:44:20] Progress: 16000/23351 labels processed, 12084 matched (75.5%)
# [20251102 06:44:20] Processing row 16001/23351...
# [20251102 06:44:20] Progress: 16100/23351 labels processed, 12146 matched (75.4%)
# [20251102 06:44:20] Processing row 16101/23351...
# [20251102 06:44:21] Progress: 16200/23351 labels processed, 12242 matched (75.6%)
# [20251102 06:44:21] Processing row 16201/23351...
# [20251102 06:44:21] Progress: 16300/23351 labels processed, 12308 matched (75.5%)
# [20251102 06:44:21] Processing row 16301/23351...
# [20251102 06:44:21] Progress: 16400/23351 labels processed, 12372 matched (75.4%)
# [20251102 06:44:21] Processing row 16401/23351...
# [20251102 06:44:21] Progress: 16500/23351 labels processed, 12427 matched (75.3%)
# [20251102 06:44:21] Processing row 16501/23351...
# [20251102 06:44:22] Progress: 16600/23351 labels processed, 12476 matched (75.2%)
# [20251102 06:44:22] Processing row 16601/23351...
# [20251102 06:44:22] Progress: 16700/23351 labels processed, 12565 matched (75.2%)
# [20251102 06:44:22] Processing row 16701/23351...
# [20251102 06:44:22] Progress: 16800/23351 labels processed, 12659 matched (75.4%)
# [20251102 06:44:22] Processing row 16801/23351...
# [20251102 06:44:22] Progress: 16900/23351 labels processed, 12747 matched (75.4%)
# [20251102 06:44:22] Processing row 16901/23351...
# [20251102 06:44:23] Progress: 17000/23351 labels processed, 12837 matched (75.5%)
# [20251102 06:44:23] Processing row 17001/23351...
# [20251102 06:44:23] Progress: 17100/23351 labels processed, 12933 matched (75.6%)
# [20251102 06:44:23] Processing row 17101/23351...
# [20251102 06:44:23] Progress: 17200/23351 labels processed, 13030 matched (75.8%)
# [20251102 06:44:23] Processing row 17201/23351...
# [20251102 06:44:23] Progress: 17300/23351 labels processed, 13106 matched (75.8%)
# [20251102 06:44:23] Processing row 17301/23351...
# [20251102 06:44:24] Progress: 17400/23351 labels processed, 13148 matched (75.6%)
# [20251102 06:44:24] Processing row 17401/23351...
# [20251102 06:44:24] Progress: 17500/23351 labels processed, 13202 matched (75.4%)
# [20251102 06:44:24] Processing row 17501/23351...
# [20251102 06:44:24] Progress: 17600/23351 labels processed, 13252 matched (75.3%)
# [20251102 06:44:24] Processing row 17601/23351...
# [20251102 06:44:24] Progress: 17700/23351 labels processed, 13314 matched (75.2%)
# [20251102 06:44:24] Processing row 17701/23351...
# [20251102 06:44:25] Progress: 17800/23351 labels processed, 13398 matched (75.3%)
# [20251102 06:44:25] Processing row 17801/23351...
# [20251102 06:44:25] Progress: 17900/23351 labels processed, 13490 matched (75.4%)
# [20251102 06:44:25] Processing row 17901/23351...
# [20251102 06:44:25] Progress: 18000/23351 labels processed, 13587 matched (75.5%)
# [20251102 06:44:25] Processing row 18001/23351...
# [20251102 06:44:25] Progress: 18100/23351 labels processed, 13666 matched (75.5%)
# [20251102 06:44:25] Processing row 18101/23351...
# [20251102 06:44:26] Progress: 18200/23351 labels processed, 13721 matched (75.4%)
# [20251102 06:44:26] Processing row 18201/23351...
# [20251102 06:44:26] Progress: 18300/23351 labels processed, 13779 matched (75.3%)
# [20251102 06:44:26] Processing row 18301/23351...
# [20251102 06:44:26] Progress: 18400/23351 labels processed, 13867 matched (75.4%)
# [20251102 06:44:26] Processing row 18401/23351...
# [20251102 06:44:26] Progress: 18500/23351 labels processed, 13961 matched (75.5%)
# [20251102 06:44:26] Processing row 18501/23351...
# [20251102 06:44:27] Progress: 18600/23351 labels processed, 14061 matched (75.6%)
# [20251102 06:44:27] Processing row 18601/23351...
# [20251102 06:44:27] Progress: 18700/23351 labels processed, 14111 matched (75.5%)
# [20251102 06:44:27] Processing row 18701/23351...
# [20251102 06:44:27] Progress: 18800/23351 labels processed, 14111 matched (75.1%)
# [20251102 06:44:27] Processing row 18801/23351...
# [20251102 06:44:27] Progress: 18900/23351 labels processed, 14134 matched (74.8%)
# [20251102 06:44:27] Processing row 18901/23351...
# [20251102 06:44:28] Progress: 19000/23351 labels processed, 14215 matched (74.8%)
# [20251102 06:44:28] Processing row 19001/23351...
# [20251102 06:44:28] Progress: 19100/23351 labels processed, 14289 matched (74.8%)
# [20251102 06:44:28] Processing row 19101/23351...
# [20251102 06:44:28] Progress: 19200/23351 labels processed, 14313 matched (74.5%)
# [20251102 06:44:28] Processing row 19201/23351...
# [20251102 06:44:28] Progress: 19300/23351 labels processed, 14366 matched (74.4%)
# [20251102 06:44:28] Processing row 19301/23351...
# [20251102 06:44:29] Progress: 19400/23351 labels processed, 14458 matched (74.5%)
# [20251102 06:44:29] Processing row 19401/23351...
# [20251102 06:44:29] Progress: 19500/23351 labels processed, 14479 matched (74.3%)
# [20251102 06:44:29] Processing row 19501/23351...
# [20251102 06:44:29] Progress: 19600/23351 labels processed, 14541 matched (74.2%)
# [20251102 06:44:29] Processing row 19601/23351...
# [20251102 06:44:29] Progress: 19700/23351 labels processed, 14636 matched (74.3%)
# [20251102 06:44:29] Processing row 19701/23351...
# [20251102 06:44:30] Progress: 19800/23351 labels processed, 14674 matched (74.1%)
# [20251102 06:44:30] Processing row 19801/23351...
# [20251102 06:44:30] Progress: 19900/23351 labels processed, 14747 matched (74.1%)
# [20251102 06:44:30] Processing row 19901/23351...
# [20251102 06:44:30] Progress: 20000/23351 labels processed, 14811 matched (74.1%)
# [20251102 06:44:30] Processing row 20001/23351...
# [20251102 06:44:30] Progress: 20100/23351 labels processed, 14903 matched (74.1%)
# [20251102 06:44:30] Processing row 20101/23351...
# [20251102 06:44:31] Progress: 20200/23351 labels processed, 14975 matched (74.1%)
# [20251102 06:44:31] Processing row 20201/23351...
# [20251102 06:44:31] Progress: 20300/23351 labels processed, 15063 matched (74.2%)
# [20251102 06:44:31] Processing row 20301/23351...
# [20251102 06:44:31] Progress: 20400/23351 labels processed, 15063 matched (73.8%)
# [20251102 06:44:31] Processing row 20401/23351...
# [20251102 06:44:31] Progress: 20500/23351 labels processed, 15088 matched (73.6%)
# [20251102 06:44:31] Processing row 20501/23351...
# [20251102 06:44:32] Progress: 20600/23351 labels processed, 15164 matched (73.6%)
# [20251102 06:44:32] Processing row 20601/23351...
# [20251102 06:44:32] Progress: 20700/23351 labels processed, 15263 matched (73.7%)
# [20251102 06:44:32] Processing row 20701/23351...
# [20251102 06:44:32] Progress: 20800/23351 labels processed, 15336 matched (73.7%)
# [20251102 06:44:32] Processing row 20801/23351...
# [20251102 06:44:32] Progress: 20900/23351 labels processed, 15336 matched (73.4%)
# [20251102 06:44:32] Processing row 20901/23351...
# [20251102 06:44:33] Progress: 21000/23351 labels processed, 15336 matched (73.0%)
# [20251102 06:44:33] Processing row 21001/23351...
# [20251102 06:44:33] Progress: 21100/23351 labels processed, 15336 matched (72.7%)
# [20251102 06:44:33] Processing row 21101/23351...
# [20251102 06:44:33] Progress: 21200/23351 labels processed, 15336 matched (72.3%)
# [20251102 06:44:33] Processing row 21201/23351...
# [20251102 06:44:33] Progress: 21300/23351 labels processed, 15336 matched (72.0%)
# [20251102 06:44:33] Processing row 21301/23351...
# [20251102 06:44:34] Progress: 21400/23351 labels processed, 15336 matched (71.7%)
# [20251102 06:44:34] Processing row 21401/23351...
# [20251102 06:44:34] Progress: 21500/23351 labels processed, 15336 matched (71.3%)
# [20251102 06:44:34] Processing row 21501/23351...
# [20251102 06:44:34] Progress: 21600/23351 labels processed, 15336 matched (71.0%)
# [20251102 06:44:34] Processing row 21601/23351...
# [20251102 06:44:35] Progress: 21700/23351 labels processed, 15336 matched (70.7%)
# [20251102 06:44:35] Processing row 21701/23351...
# [20251102 06:44:35] Progress: 21800/23351 labels processed, 15336 matched (70.3%)
# [20251102 06:44:35] Processing row 21801/23351...
# [20251102 06:44:35] Progress: 21900/23351 labels processed, 15336 matched (70.0%)
# [20251102 06:44:35] Processing row 21901/23351...
# [20251102 06:44:35] Progress: 22000/23351 labels processed, 15336 matched (69.7%)
# [20251102 06:44:35] Processing row 22001/23351...
# [20251102 06:44:36] Progress: 22100/23351 labels processed, 15336 matched (69.4%)
# [20251102 06:44:36] Processing row 22101/23351...
# [20251102 06:44:36] Progress: 22200/23351 labels processed, 15336 matched (69.1%)
# [20251102 06:44:36] Processing row 22201/23351...
# [20251102 06:44:36] Progress: 22300/23351 labels processed, 15336 matched (68.8%)
# [20251102 06:44:36] Processing row 22301/23351...
# [20251102 06:44:36] Progress: 22400/23351 labels processed, 15336 matched (68.5%)
# [20251102 06:44:36] Processing row 22401/23351...
# [20251102 06:44:37] Progress: 22500/23351 labels processed, 15336 matched (68.2%)
# [20251102 06:44:37] Processing row 22501/23351...
# [20251102 06:44:37] Progress: 22600/23351 labels processed, 15336 matched (67.9%)
# [20251102 06:44:37] Processing row 22601/23351...
# [20251102 06:44:37] Progress: 22700/23351 labels processed, 15336 matched (67.6%)
# [20251102 06:44:37] Processing row 22701/23351...
# [20251102 06:44:37] Progress: 22800/23351 labels processed, 15336 matched (67.3%)
# [20251102 06:44:37] Processing row 22801/23351...
# [20251102 06:44:38] Progress: 22900/23351 labels processed, 15336 matched (67.0%)
# [20251102 06:44:38] Processing row 22901/23351...
# [20251102 06:44:38] Progress: 23000/23351 labels processed, 15336 matched (66.7%)
# [20251102 06:44:38] Processing row 23001/23351...
# [20251102 06:44:38] Progress: 23100/23351 labels processed, 15336 matched (66.4%)
# [20251102 06:44:38] Processing row 23101/23351...
# [20251102 06:44:38] Progress: 23200/23351 labels processed, 15336 matched (66.1%)
# [20251102 06:44:38] Processing row 23201/23351...
# [20251102 06:44:39] Progress: 23300/23351 labels processed, 15336 matched (65.8%)
# [20251102 06:44:39] Processing row 23301/23351...
# [20251102 06:44:39] ========================================
# [20251102 06:44:39] Matching complete!
# [20251102 06:44:39] ========================================
# [20251102 06:44:39] Writing JSON to: /home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Label.json
# [20251102 06:44:39] JSON written successfully (15336 entries)
# [20251102 06:44:39] Writing Excel to: /home/hice1/ssinha348/scratch/stonemt_cameratrap/Camera Trap Photos/Final_Label_with_paths.xlsx
# [20251102 06:44:45] Excel written successfully
# [20251102 06:44:45] ========================================
# [20251102 06:44:45] FINAL SUMMARY
# [20251102 06:44:45] ========================================
# [20251102 06:44:45] Total labels processed: 23351
# [20251102 06:44:45] Successfully matched: 15336
# [20251102 06:44:45] Unmatched: 8015
# [20251102 06:44:45] Match rate: 65.7%
# [20251102 06:44:45] ========================================
# [20251102 06:44:45] DONE!
